# %% [markdown]
# # Processing of US Coastguard GPS disruption data

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ### Installs

# %%
# %pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-6.0.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Downloading lxml-6.0.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 78.7 MB/s eta 0:00:00
# Installing collected packages: lxml
# Successfully installed lxml-6.0.0
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Imports

# %%
import pandas as pd
from datetime import datetime as dt

# %% [markdown]
# ## Webscrape
# Run this to webscrape the data to files. If you already have the data locally, skip this section.

# %% [markdown]
# ### Web scrape GPS interruptions

# %%
table_list = pd.read_html(r'https://navcen.uscg.gov/gps-problem-report-status')

# %%
table_list[0].to_csv('gps_navcen.csv',index=False)

# %% [markdown]
# ## Processing and Analysis

# %% [markdown]
# ### Load from csv files

# %%
gps_disruption_df=pd.read_csv('gps_navcen.csv')

# %%
gps_disruption_df['User']=gps_disruption_df['Description'].str.split(pat='NAVCEN:',n=1,expand=True)[0]
gps_disruption_df['NAVCEN']=gps_disruption_df['Description'].str.split(pat='NAVCEN:',n=1,expand=True)[1]

# %%
gps_disruption_df
# Out:
#                          Disruption Date/Time  \
# 0    04/24/2024 22:35:00 Eastern African Time
# 1    04/18/2024 17:52:00 Eastern African Time
# 2        04/12/2024 11:20:00 Middle East Time
# 3    04/11/2024 12:30:00 Eastern African Time
# 4                     04/11/2024 18:38:00 GMT
# ..                                        ...
# 544                      01/03/2017 11:AM CST
# 545                       01/02/2017 3:00 EST
# 546                      01/01/2017 12:00 EST
# 547                       11/16/2016 7h37 UTC
# 548                   06/22/1976 00:08:31 EST
#
#                                    Location            Type  \
# 0                                       NaN  Communications
# 1                                       NaN          Marine
# 2                                       NaN             NaN
# 3                                       NaN          Marine
# 4                                       NaN          Marine
# ..                                      ...             ...
# 544                      San Angelo Airport        Aviation
# 545  North Carolina - South Carolina border  Transportation
# 546                           Elizabeth, NJ  Transportation
# 547                          Rennes, France        Research
# 548                                     NaN           Other
#
#                                            Description  \
# 0    USER: VSAT Communications including Data and v...
# 1    USER: Bab El Mandeb strait NAVCEN: The GPS Ope...
# 2    USER: CALLER REPORTED A POSSIBLE CYBER SECURIT...
# 3    USER: Our vessel on entering Gulf of Aqaba exp...
# 4    USER: On 11th April, 1838 UTC, MT Toya while a...
# ..                                                 ...
# 544  User: The GPS systems in normal mode not milit...
# 545  User: GPS would say when you plug in that ther...
# 546  User: My business is located in Elizabeth, NJ....
# 547  User: I experimented high range error on PRN 3...
# 548  USER: Ongoing issues NAVCEN: The GPS Operation...
#
#                           Cause Closed Date  \
# 0          Unknown Interference  04/30/2024
# 1          Unknown Interference  04/22/2024
# 2          Unknown Interference  04/15/2024
# 3          Unknown Interference  04/15/2024
# 4          Unknown Interference  04/15/2024
# ..                          ...         ...
# 544  Unintentional Interference  05/20/2019
# 545              User Equipment  05/20/2019
# 546               Mapping Issue  05/20/2019
# 547              User Equipment  05/20/2019
# 548    Insufficient Information  08/14/2023
#
#                                                   User  \
# 0    USER: VSAT Communications including Data and v...
# 1                          USER: Bab El Mandeb strait
# 2    USER: CALLER REPORTED A POSSIBLE CYBER SECURIT...
# 3    USER: Our vessel on entering Gulf of Aqaba exp...
# 4    USER: On 11th April, 1838 UTC, MT Toya while a...
# ..                                                 ...
# 544  User: The GPS systems in normal mode not milit...
# 545  User: GPS would say when you plug in that ther...
# 546  User: My business is located in Elizabeth, NJ....
# 547  User: I experimented high range error on PRN 3...
# 548                              USER: Ongoing issues
#
#                                                 NAVCEN
# 0     The GPS Operations Center reviewed the GPS Co...
# 1     The GPS Operations Center reviewed the GPS Co...
# 2     The GPS Operations Center reviewed the GPS Co...
# 3     The GPS Operations Center reviewed the GPS Co...
# 4     The GPS Operations Center reviewed the GPS Co...
# ..                                                 ...
# 544   Report referred to FCC. FCC conducted an inve...
# 545   The GPS Operations Center reviewed the GPS Co...
# 546   User provided information on how to contact m...
# 547   The GPS Operations Center reviewed the GPS Co...
# 548   The GPS Operations Center reviewed the GPS Co...
#
# [549 rows x 8 columns]

# %% [markdown]
# ## Analyse disruptions by date

# %%
gps_disruption_df['local_date']=gps_disruption_df['Disruption Date/Time']\
.apply(lambda x:dt.strptime(x[0:10],'%m/%d/%Y'))

# %% [markdown]
# The local date is the UTC date with up to 0.5 day error. That's not bad for analysis to the nearest day. This will have to be improved for more precise analysis.

# %%
(gps_disruption_df
    .resample('ME', on='local_date')
    .count()
    [['Disruption Date/Time']]
    .loc["2016":]
    .plot(rot=90)
)
# Out:
# <Axes: xlabel='local_date'>

# %% [markdown]
# ## Analyse disruptions by location

# %% [markdown]
# ### Clean up Location to get country/code

# %%
gps_disruption_df['location_state_country']=(gps_disruption_df['Location'].str.upper()
 .str.split(pat=',',n=1,expand=True)[1].str.strip()
 .combine_first(
     gps_disruption_df['Location'].str.upper()
     .str.split(pat=',',n=1,expand=True)[0].str.strip()
 )
 #.combine_first(list(sovereign_states['Country name (using title case)']) in gps_disruption_df['Location']
 .replace('LIMASSOL','CYPRUS')
 .replace('STRAIT OF HORMUZ','IRAN')
 .replace('STRAITS OF HORMUZ','IRAN')
 .replace('PRC','CHINA')
 .replace('EAST OF MALTA','MALTA') #.contains approach?
 .replace('ISTANBUL','TURKEY')
 .replace('SUEZ CANAL','EGYPT')
                                             
)

# %%
gps_disruption_df[['Location','location_state_country','Cause']]
# Out:
#                                    Location  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 544                      San Angelo Airport
# 545  North Carolina - South Carolina border
# 546                           Elizabeth, NJ
# 547                          Rennes, France
# 548                                     NaN
#
#                      location_state_country                       Cause
# 0                                       NaN        Unknown Interference
# 1                                       NaN        Unknown Interference
# 2                                       NaN        Unknown Interference
# 3                                       NaN        Unknown Interference
# 4                                       NaN        Unknown Interference
# ..                                      ...                         ...
# 544                      SAN ANGELO AIRPORT  Unintentional Interference
# 545  NORTH CAROLINA - SOUTH CAROLINA BORDER              User Equipment
# 546                                      NJ               Mapping Issue
# 547                                  FRANCE              User Equipment
# 548                                     NaN    Insufficient Information
#
# [549 rows x 3 columns]

# %% [markdown]
# ### Cause Analysis

# %%
gps_disruption_df.groupby('Cause').count()['Disruption Date/Time'].sort_values().plot(kind='barh')
# Out:
# <Axes: ylabel='Cause'>

# %% [markdown]
# ### Focus on Unknown Interference

# %%
gps_disruption_counted=(gps_disruption_df[gps_disruption_df['location_state_country'].notna() 
    & gps_disruption_df.Cause.str.contains('Unknown Interference')]
                        .groupby('location_state_country')
                        .count()['Disruption Date/Time']
                        .sort_values()
                       )

# %%
gps_disruption_counted[gps_disruption_counted>1].plot(kind='barh',figsize=[9,7])
# Out:
# <Axes: ylabel='location_state_country'>

# %%
(gps_disruption_df
    .query("location_state_country in "+'[\"'+'\",\"'.join(list(gps_disruption_counted[gps_disruption_counted>3].index))+'\"]')
    .groupby(['local_date','location_state_country'])
    .count()
    [['Disruption Date/Time']]
    .unstack() 
    .resample('12ME')
    .sum()
    .plot(rot=90,marker='.')#,kind='bar')
    .legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
)

# %%
gps_disruption_counted[gps_disruption_counted==1].plot(kind='barh',figsize=[9,20])
# Out:
# <Axes: ylabel='location_state_country'>

# %% [markdown]
# ### Focus on testing

# %%
gps_testing_counted=(gps_disruption_df.query('location_state_country.notna() & Cause.str.contains("GPS Testing")')
                        .groupby('location_state_country')
                        .count()['Disruption Date/Time']
                        
                        .sort_values()
                       )

# %%
gps_testing_counted.plot(kind='barh',figsize=[9,7])
# Out:
# <Axes: ylabel='location_state_country'>
