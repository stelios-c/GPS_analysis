# %% [markdown]
# # Satellite navigation disturbances in Finland

# %%
# %pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-5.4.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.5 kB)
# Downloading lxml-5.4.0-cp312-cp312-manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 77.8 MB/s eta 0:00:00
# Installing collected packages: lxml
# Successfully installed lxml-5.4.0
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# required on Codespaces for pd.read_html()

# %%
# %pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: numpy>=1.22 in /home/codespace/.local/lib/python3.12/site-packages (from geopandas) (2.1.1)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.10.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.12/site-packages (from geopandas) (24.1)
# Requirement already satisfied: pandas>=1.4.0 in /home/codespace/.local/lib/python3.12/site-packages (from geopandas) (2.2.3)
# Collecting pyproj>=3.3.0 (from geopandas)
#   Downloading pyproj-3.7.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas)
#   Downloading shapely-2.0.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas>=1.4.0->geopandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas>=1.4.0->geopandas) (2024.2)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from pyogrio>=0.7.2->geopandas) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
# Downloading pyogrio-0.10.0-cp312-cp312-manylinux_2_28_x86_64.whl (24.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 65.9 MB/s eta 0:00:00:00:01
# Downloading pyproj-3.7.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 65.2 MB/s eta 0:00:00
# Downloading shapely-2.0.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 28.6 MB/s eta 0:00:00
# Installing collected packages: shapely, pyproj, pyogrio, geopandas
# Successfully installed geopandas-1.0.1 pyogrio-0.10.0 pyproj-3.7.0 shapely-2.0.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import datetime as dt
import geopandas
import matplotlib.pyplot as plt

# %%
url='situational-picture-disturbances-satellite-navigation-finland-2024'
(pd
 .read_html('https://www.traficom.fi/en/news/'+url)
 [0]
 .to_csv('finland_disturbance.csv',index=False)
)

# %% [markdown]
# Save data locally to avoid webscraping everytime I rerun the notebook.

# %%
fi_data=pd.read_csv('finland_disturbance.csv',header=1)

# %%
fi_data
# Out:
#                  Year      Finland  \
# 0                2018            0
# 1                2019            8
# 2                2020           27
# 3                2021            8
# 4                2022           65
# 5                2023          239
# 6  2024 (by 30 April)  Around 1200
#
#   Finnish operators’ notifications outside of Finland
# 0                                                  6
# 1                                                137
# 2                                                 34
# 3                                                 71
# 4                                               1331
# 5                                               7370
# 6                                        Around 2100

# %% [markdown]
# Unfortunately the last line is not purely numeric and needs some cleanup.

# %%
def parse_date(input_str):
    return dt.datetime.strptime(input_str,'%d %B %Y')
def clean_table(df):
    return df.assign(
        disturbance_year=fi_data
        .Year.str.split(' ',expand=True)[0].astype('int32'),
        end_date =(fi_data
        .Year.str.split('by ',expand=True)[1].str.rstrip(')').fillna('31 December')+' '+fi_data
        .Year.str.split(' ',expand=True)[0]).apply(parse_date).dt.dayofyear,
        disturbances_Finland=fi_data
        .Finland.str.replace('Around ','').astype('int32'),
        disturbances_Outside=fi_data
        ['Finnish operators’ notifications outside of Finland']
        .str.replace('Around ','').astype('int32'),
        disturbances_Outside_weighted=fi_data
        ['Finnish operators’ notifications outside of Finland']
        .str.replace('Around ','').astype('int32')*365/(fi_data
        .Year.str.split('by ',expand=True)[1].str.rstrip(')').fillna('31 December')+' '+fi_data
        .Year.str.split(' ',expand=True)[0]).apply(parse_date).dt.dayofyear,
        disturbances_Finland_weighted=fi_data
        .Finland.str.replace('Around ','').astype('int32')*365/(fi_data
        .Year.str.split('by ',expand=True)[1].str.rstrip(')').fillna('31 December')+' '+fi_data
        .Year.str.split(' ',expand=True)[0]).apply(parse_date).dt.dayofyear
        )

# %%
print(dt.datetime.strptime('30 April 2024','%d %B %Y'))
# Out:
# 2024-04-30 00:00:00

# %%
print(parse_date('30 April 2024'))
# Out:
# 2024-04-30 00:00:00

# %%
(fi_data
 .pipe(clean_table)
 .set_index('disturbance_year')
 [['disturbances_Finland','disturbances_Outside']]
 .plot(subplots=True)
)
# Out:
# array([<Axes: xlabel='disturbance_year'>,
#        <Axes: xlabel='disturbance_year'>], dtype=object)

# %%
(fi_data
 .pipe(clean_table)
 .set_index('disturbance_year')[['disturbances_Finland','disturbances_Outside']]
 .corr(numeric_only=True)
)
# Out:
#                       disturbances_Finland  disturbances_Outside
# disturbances_Finland              1.000000              0.272785
# disturbances_Outside              0.272785              1.000000

# %%
(fi_data
 .pipe(clean_table)
 .set_index('disturbance_year')
 [['disturbances_Finland_weighted','disturbances_Outside_weighted']]
 .plot(subplots=True)
)
# Out:
# array([<Axes: xlabel='disturbance_year'>,
#        <Axes: xlabel='disturbance_year'>], dtype=object)

# %%
(fi_data
 .pipe(clean_table)
 .set_index('disturbance_year')
 [['disturbances_Finland_weighted','disturbances_Outside_weighted']]
 .corr(numeric_only=True)
)
# Out:
#                                disturbances_Finland_weighted  \
# disturbances_Finland_weighted                       1.000000
# disturbances_Outside_weighted                       0.615289
#
#                                disturbances_Outside_weighted
# disturbances_Finland_weighted                       0.615289
# disturbances_Outside_weighted                       1.000000

# %%
(fi_data
 .pipe(clean_table)
)
# Out:
#                  Year      Finland  \
# 0                2018            0
# 1                2019            8
# 2                2020           27
# 3                2021            8
# 4                2022           65
# 5                2023          239
# 6  2024 (by 30 April)  Around 1200
#
#   Finnish operators’ notifications outside of Finland  disturbance_year  \
# 0                                                  6               2018
# 1                                                137               2019
# 2                                                 34               2020
# 3                                                 71               2021
# 4                                               1331               2022
# 5                                               7370               2023
# 6                                        Around 2100               2024
#
#    end_date  disturbances_Finland  disturbances_Outside  \
# 0       365                     0                     6
# 1       365                     8                   137
# 2       366                    27                    34
# 3       365                     8                    71
# 4       365                    65                  1331
# 5       365                   239                  7370
# 6       121                  1200                  2100
#
#    disturbances_Outside_weighted  disturbances_Finland_weighted
# 0                       6.000000                       0.000000
# 1                     137.000000                       8.000000
# 2                      33.907104                      26.926230
# 3                      71.000000                       8.000000
# 4                    1331.000000                      65.000000
# 5                    7370.000000                     239.000000
# 6                    6334.710744                    3619.834711

# %% [markdown]
# Note we do want to normalise leap years! But it won't make a big difference, unlike the incomplete 2024.

# %%
(fi_data
 .pipe(clean_table)
 .set_index('disturbance_year')
 [['disturbances_Finland_weighted']]
 .assign(disturbances_Outside_shifted=fi_data
         .pipe(clean_table)
         .set_index('disturbance_year')
         [['disturbances_Outside_weighted']]
         .shift(periods=1)
        )
 .plot(subplots=True)
)
# Out:
# array([<Axes: xlabel='disturbance_year'>,
#        <Axes: xlabel='disturbance_year'>], dtype=object)

# %%
(fi_data
 .pipe(clean_table)
 .set_index('disturbance_year')
 [['disturbances_Finland_weighted']]
 .assign(disturbances_Outside_shifted=fi_data
         .pipe(clean_table)
         .set_index('disturbance_year')
         [['disturbances_Outside_weighted']]
         .shift(periods=1)
        )
 .corr()
)
# Out:
#                                disturbances_Finland_weighted  \
# disturbances_Finland_weighted                       1.000000
# disturbances_Outside_shifted                        0.993154
#
#                                disturbances_Outside_shifted
# disturbances_Finland_weighted                      0.993154
# disturbances_Outside_shifted                       1.000000

# %%
world = geopandas.read_file("https://naciscdn.org/naturalearth/10m/cultural/ne_10m_admin_0_countries.zip").clip([3, 45, 42, 72]).dropna(axis='columns',how='all')

# %%
ax = (world
 .assign(
     colour= world.SOVEREIGNT.where(world.SOVEREIGNT.str.match('Finland') | world.SOVEREIGNT.str.match('Russia'),'other')
 )
).plot(column='colour',legend=True)
plt.show()

# %% [markdown]
# Theory: what happened in Kaliningrad in 2023 is happening in St Petersburg , Karelia and Arctic in 2024? Website mentions specific areas outside Finland:
# > There have been numerous notifications of interference in the Black Sea, Kaliningrad and the Gulf of Finland areas.
